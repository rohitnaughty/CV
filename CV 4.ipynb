# %% [markdown]
# 1. What is the concept of cyclical momentum?

# %% [markdown]
# Momentum in neural networks is a variant of the stochastic gradient descent. It replaces the gradient with a momentum which is
# an aggregate of gradients as very well explained here. It is also the common name given to the momentum factor, as in cnn.

# %% [markdown]
# 2. What callback keeps track of hyperparameter values (along with other data) during
# training?

# %% [markdown]
# PARAMS = {'epoch_nr': 5, 'batch_size': 64, 'dense': 256, 'optimizer': 'sgd', 'metrics': ['accuracy', 'binary_accuracy'], 'activation': 'elu'}

# %% [markdown]
# 3. In the color dim plot, what does one column of pixels represent?

# %% [markdown]
# row and column number

# %% [markdown]
# 4. In color dim, what does "poor teaching" look like? What is the reason for this?

# %% [markdown]
# Lack of use of modern technology during teaching.

# %% [markdown]
# 5. Does a batch normalization layer have any trainable parameters?

# %% [markdown]
# Two learnable parameters called beta and gamma.

# %% [markdown]
# 6. In batch normalization during preparation, what statistics are used to normalize? What
# about during the validation process?

# %% [markdown]
# It normalizes the activation using mini-batch statistics during training but the estimated population statistics during
# inference.

# %% [markdown]
# 7. Why do batch normalization layers help models generalize better?

# %% [markdown]
# It helps by making the data flowing between intermediate layers of the neural network look, this means you can use a higher
# learning rate.

# %% [markdown]
# 8.Explain between MAX POOLING and AVERAGE POOLING is number eight.

# %% [markdown]
# Average pooling method smooths out the image and hence the sharp features may not be identified when this pooling method is
# used.Max pooling selects the brighter pixels from the image.

# %% [markdown]
# 9. What is the purpose of the POOLING LAYER?

# %% [markdown]
# Pooling layers are used to reduce the dimensions of the feature maps.Thus, it reduces the number of parameters to learn and
# the amount of computation performed in the network.
#
# The pooling layer summarised the features present  in  a region of the feature map generated by a convolution layer.

# %% [markdown]
# 10. Why do we end up with Completely CONNECTED LAYERS?

# %% [markdown]
# The purpose of the f.c layer can be thought like non-linear PCA, it rectifies the "good" features and diminishes the others
# via learning the full set of weights.

# %% [markdown]
# 11. What do you mean by PARAMETERS?

# %% [markdown]
# An arbitrary constant whose value characterizes a member of a system.

# %% [markdown]
# 12. What formulas are used to measure these PARAMETERS?

# %% [markdown]
# Trial and error on different set of dataset then check accuracy.
